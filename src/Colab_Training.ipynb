# %% [markdown]
# <a href="https://colab.research.google.com/github/Baronphviet/hybrid-quantum-gnn-5g-ids/blob/main/src/Colab_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Colab Workspace for NCKH
#
# Đây là notebook được thiết lập sẵn để bạn có thể mở và chạy trực tiếp trên **Google Colab**.
# Nó đã bao gồm sẵn các đoạn code để clone tự động dữ liệu và mã nguồn từ GitHub về Colab.

# %%
# 1. Clone repository chứa dữ liệu và mã nguồn về môi trường Colab
# !git clone https://github.com/Baronphviet/hybrid-quantum-gnn-5g-ids.git
# %cd hybrid-quantum-gnn-5g-ids
# !ls

# %%
# 2. Kiểm tra dữ liệu thô (ví dụ file tron.csv)
import os
if os.path.exists('data/raw/tron.csv'):
    print("Dữ liệu tron.csv đã sẵn sàng!")
else:
    print("Không tìm thấy file dữ liệu, vui lòng kiểm tra lại.")

# %%
# 3. Cài đặt các thư viện cần thiết cho QGNN và GNN
# Bỏ comment dòng dưới để cài đặt khi cần thiết
# !pip install torch_geometric qiskit
